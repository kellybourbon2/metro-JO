# %%
import io

# %%
# %run "Programmes.ipynb"
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Affluence à 09:35 à la station bastille, sur la ligne 1 : 15
# Affluence sur la ligne 1 à 09:35: 434
# Le nombre de personnes supplémentaires à la station bastille en raison des JO est 153.
# Le nombre de personnes supplémentaires sur la ligne 1 en raison des JO est 17000.
# Nombre de personnes totales à la station bastille sur la ligne 1 à 09:35: 213
# Nombre de personnes totales sur la ligne 1 à 09:35: 22434
# Pas de panique, le trafic risque de se modérer prochainement. À 10:35, il y aura 67 personnes à la station bastille sur la ligne 1.

# %%
# %run "Informations lignes métro.ipynb"
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Tableau importé : trafic des entrants directs sur le réseau ferré RATP en 2021
#      Rang Réseau                 Station    Trafic Correspondance_1  \
# 0       7  Métro              REPUBLIQUE  11079708                3
# 1       9  Métro              LA DEFENSE   9256802                1
# 2      13  Métro          HOTEL DE VILLE   7251729                1
# 3      30  Métro  VILLEJUIF-LOUIS ARAGON   5218070                7
# 4      40  Métro            PALAIS-ROYAL   4822599                1
# ..    ...    ...                     ...       ...              ...
# 366    33    RER        NOGENT-SUR-MARNE   2358276                A
# 367    43    RER                 BAGNEUX   1742783                B
# 368    44    RER   LE PARC DE SAINT-MAUR   1617366                A
# ...

# %%
import datetime
import pandas as pd
import folium

affluence_data = generate_affluence_data()

# Générer les données de stations par ligne
stations_par_ligne = {}

for numero_ligne in ["1", "2", "3", "3bis", "4", "5", "6", "7", "7bis", "8", "9", "10", "11", "12", "13", "14"]:
    numero_str = str(numero_ligne)
    ligne_data = pd.read_csv(f'ligne_numero_{numero_str}.csv')
    stations_par_ligne[f"Ligne {numero_str}"] = ligne_data.set_index('Station').to_dict()['Rang']

# Créer les cartes
for date, affluences in affluence_data.items():
    map_metro = folium.Map(location=[48.8566, 2.3522], zoom_start=12)  # Coordonnées de Paris

    for station, affluence in affluences.items():
        # Remplace cette partie par la vraie latitude et longitude de la station
        latitude = 48.8566
        longitude = 2.3522

        # Ajouter un marqueur pour chaque station avec une taille proportionnelle à l'affluence
        folium.CircleMarker(
            location=[latitude, longitude],
            radius=affluence / 5000,  # Ajuster le facteur de mise à l'échelle selon les besoins
            popup=f"{station}: {affluence} personnes",
            color='blue',
            fill=True,
            fill_color='blue'
        ).add_to(map_metro)

    map_metro.save(f"metro_map_{date}.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 5
#       2 import pandas as pd
#       3 import folium
# ----> 5 affluence_data = generate_affluence_data()
#       7 # Générer les données de stations par ligne
#       8 stations_par_ligne = {}
#
# Cell In[54], line 15, in generate_affluence_data()
#      12 date_str = single_date.strftime("%Y-%m-%d")
#      13 affluence_data[date_str] = {}
# ---> 15 for index, row in stations.iterrows():
#      16     station_name = row["Libelle station"]
#      17     total_affluence = 0
#
# NameError: name 'stations' is not defined
